# %%
import pandas as pd

df = pd.read_csv("features.csv")
df.head()
# Out:
#         zcr      rmse  spectral_centroid  spectral_bandwidth       rolloff  \
# 0  0.078671  0.005266        4145.632542         5038.249864   8998.059870
# 1  0.096239  0.020122        4914.428175         5295.787392  10706.870727
# 2  0.086954  0.006556        4144.127362         4816.062277   8727.286672
# 3  0.089911  0.008303        4473.216471         5060.716079   9461.822416
# 4  0.096233  0.005311        4454.264244         4905.998074   8963.951644
#
#    pitch_mean   pitch_std     mfcc_1      mfcc_2     mfcc_3  ...  \
# 0  139.974711   84.100281 -562.19244  100.194470  43.463394  ...
# 1  140.369699   92.894198 -412.75348   58.734497  25.513817  ...
# 2  127.210277  100.072157 -521.32684  108.498970  28.073830  ...
# 3  148.031263   95.911699 -511.29280  100.932000  26.685370  ...
# 4  158.949875   91.978017 -545.97510   88.971954  24.629852  ...
#
#    delta_mfcc_9  delta_mfcc_10  delta_mfcc_11  delta_mfcc_12  delta_mfcc_13  \
# ...

# %%
df.info() #datatypes and non null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   zcr                 73 non-null     float64
#  1   rmse                73 non-null     float64
#  2   spectral_centroid   73 non-null     float64
#  3   spectral_bandwidth  73 non-null     float64
#  4   rolloff             73 non-null     float64
#  5   pitch_mean          73 non-null     float64
#  6   pitch_std           73 non-null     float64
#  7   mfcc_1              73 non-null     float64
#  8   mfcc_2              73 non-null     float64
#  9   mfcc_3              73 non-null     float64
#  10  mfcc_4              73 non-null     float64
#  11  mfcc_5              73 non-null     float64
#  12  mfcc_6              73 non-null     float64
#  13  mfcc_7              73 non-null     float64
#  14  mfcc_8              73 non-null     float64
# ...

# %%
df.describe() #summary of statistics
# Out:
#              zcr       rmse  spectral_centroid  spectral_bandwidth  \
# count  73.000000  73.000000          73.000000           73.000000
# mean    0.080613   0.008575        4530.747922         5311.143782
# std     0.015523   0.004488         484.844203          381.530084
# min     0.022159   0.002698        2355.967792         4155.043138
# 25%     0.071138   0.005704        4234.070942         5027.219681
# 50%     0.080084   0.007008        4608.880265         5304.658253
# 75%     0.090054   0.009381        4821.323708         5470.438673
# max     0.107964   0.021648        5560.679970         6138.616602
#
#             rolloff  pitch_mean   pitch_std      mfcc_1      mfcc_2  \
# count     73.000000   73.000000   73.000000   73.000000   73.000000
# mean   10138.236548  139.713385  102.342943 -525.633399   85.357022
# std     1292.151319   20.144359   15.259146   43.218361   13.492418
# min     4745.980638  100.625677   57.911869 -621.077640   48.899384
# ...

# %%
#deleting column jitter_local and shimmer_local
df = df.drop(columns = ['jitter_local','shimmer_local'])

# %%
df.isnull().sum() #checking missing values
# Out:
# zcr                   0
# rmse                  0
# spectral_centroid     0
# spectral_bandwidth    0
# rolloff               0
# pitch_mean            0
# pitch_std             0
# mfcc_1                0
# mfcc_2                0
# mfcc_3                0
# mfcc_4                0
# mfcc_5                0
# mfcc_6                0
# mfcc_7                0
# mfcc_8                0
# mfcc_9                0
# mfcc_10               0
# mfcc_11               0
# mfcc_12               0
# mfcc_13               0
# delta_mfcc_1          0
# delta_mfcc_2          0
# delta_mfcc_3          0
# delta_mfcc_4          0
# delta_mfcc_5          0
# delta_mfcc_6          0
# delta_mfcc_7          0
# delta_mfcc_8          0
# delta_mfcc_9          0
# delta_mfcc_10         0
# delta_mfcc_11         0
# delta_mfcc_12         0
# delta_mfcc_13         0
# label                 0
# recording_type        0
# filename              0
# dtype: int64

# %%
# checking for duplicated columns
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

if "recording_type" in df.columns:
    le = LabelEncoder()
    df["recording_type"] = le.fit_transform(df["recording_type"])

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop(columns=["label", "filename"], errors="ignore")
y = df["label"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Histogram of features
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df.hist(figsize=(15,12));

# %%
# Correlation Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), cmap="coolwarm", annot=False)
# Out:
# <Axes: >

# %%
# Class distribution
df['label'].value_counts().plot(kind='bar');

# %%
#saving cleaned dataset
df.to_csv("features_cleaned.csv", index=False)
