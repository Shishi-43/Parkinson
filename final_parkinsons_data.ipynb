# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_df = pd.read_csv("final_parkinsons_data.csv")
final_df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0   237.226000    247.326000    225.227000        0.002980          0.000010
# 1   170.368000    268.796000     79.543000        0.005710          0.000030
# 2   114.265355    538.212829     75.110317        0.039317          0.000367
# 3   114.847000    271.314000    104.680000        0.008670          0.000080
# 4   243.439000    250.912000    232.435000        0.002100          0.000009
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0  0.001690  0.001820    0.005070      0.017520          0.164000  ...
# 1  0.002320  0.002690    0.006960      0.032730          0.281000  ...
# 2  0.016847  0.018132    0.050542      0.126063          1.186518  ...
# 3  0.003730  0.005200    0.011200      0.032250          0.350000  ...
# 4  0.001090  0.001370    0.003270      0.014190          0.126000  ...
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       268 non-null    float64
#  1   MDVP:Fhi(Hz)      268 non-null    float64
#  2   MDVP:Flo(Hz)      268 non-null    float64
#  3   MDVP:Jitter(%)    268 non-null    float64
#  4   MDVP:Jitter(Abs)  268 non-null    float64
#  5   MDVP:RAP          268 non-null    float64
#  6   MDVP:PPQ          268 non-null    float64
#  7   Jitter:DDP        268 non-null    float64
#  8   MDVP:Shimmer      268 non-null    float64
#  9   MDVP:Shimmer(dB)  268 non-null    float64
#  10  Shimmer:APQ3      268 non-null    float64
#  11  Shimmer:APQ5      268 non-null    float64
#  12  MDVP:APQ          268 non-null    float64
#  13  Shimmer:DDA       268 non-null    float64
#  14  NHR               268 non-null    float64
#  15  HNR               268 non-null    float64
# ...

# %%
final_df.isnull().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# label               0
# dtype: int64

# %%
final_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   268.000000    268.000000    268.000000      268.000000
# mean    158.608193    297.723287    105.755497        0.010642
# std      39.567055    184.564298     41.114120        0.008858
# min      88.333000    102.145000     65.476000        0.001680
# 25%     121.977250    148.782000     75.690147        0.004023
# 50%     153.941500    211.782500     89.587000        0.006490
# 75%     187.886810    506.083663    114.033250        0.017183
# max     260.105000    599.901743    239.170000        0.039317
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        268.000000  268.000000  268.000000  268.000000    268.000000
# mean           0.000072    0.005028    0.005340    0.015084      0.046595
# std            0.000065    0.004046    0.004184    0.012137      0.033731
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
final_df['label'].value_counts()
# Out:
# label
# 1    178
# 0     90
# Name: count, dtype: int64

# %%
numeric_df = final_df.select_dtypes(include=['float64', 'int64'])
numeric_df.hist(figsize=(15,12));

# %%
plt.figure(figsize=(12,8))
sns.heatmap(final_df.select_dtypes(include=['float64', 'int64']).corr(), cmap="coolwarm", annot=False)
# Out:
# <Axes: >
